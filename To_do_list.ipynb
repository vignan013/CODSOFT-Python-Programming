# %% [markdown]
# <a href="https://colab.research.google.com/github/vignan013/CODSOFT-Python-Programming/blob/main/To_do_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

class ToDoList:
    def __init__(self):
        self.tasks = []

    def add_task(self, task):
        self.tasks.append({'task': task, 'completed': False})
        print(f'Task "{task}" added.')

    def remove_task(self, index):
        try:
            removed_task = self.tasks.pop(index)
            print(f'Task "{removed_task["task"]}" removed.')
        except IndexError:
            print("Invalid task number.")

    def complete_task(self, index):
        try:
            self.tasks[index]['completed'] = True
            print(f'Task "{self.tasks[index]["task"]}" marked as completed.')
        except IndexError:
            print("Invalid task number.")

    def update_task(self, index, new_task):
        try:
            self.tasks[index]['task'] = new_task
            print(f'Task updated to "{new_task}".')
        except IndexError:
            print("Invalid task number.")

    def show_tasks(self):
        if not self.tasks:
            print("No tasks in the list.")
            return
        for i, task in enumerate(self.tasks):
            status = 'Done' if task['completed'] else 'Not Done'
            print(f"{i + 1}. {task['task']} - {status}")

def clear_screen():
    os.system('cls' if os.name == 'nt' else 'clear')

def main():
    to_do_list = ToDoList()

    while True:
        clear_screen()
        print("To-Do List Application")
        print("1. Show tasks")
        print("2. Add task")
        print("3. Remove task")
        print("4. Complete task")
        print("5. Update task")
        print("6. Exit")

        choice = input("Choose an option: ")

        if choice == '1':
            clear_screen()
            to_do_list.show_tasks()
        elif choice == '2':
            task = input("Enter the task: ")
            to_do_list.add_task(task)
        elif choice == '3':
            index = int(input("Enter the task number to remove: ")) - 1
            to_do_list.remove_task(index)
        elif choice == '4':
            index = int(input("Enter the task number to mark as completed: ")) - 1
            to_do_list.complete_task(index)
        elif choice == '5':
            index = int(input("Enter the task number to update: ")) - 1
            new_task = input("Enter the new task: ")
            to_do_list.update_task(index, new_task)
        elif choice == '6':
            break
        else:
            print("Invalid choice. Please try again.")

        input("Press Enter to continue...")

if __name__ == "__main__":
    main()
# Out:
# To-Do List Application
# 1. Show tasks
# 2. Add task
# 3. Remove task
# 4. Complete task
# 5. Update task
# 6. Exit
# Choose an option: 2
# Enter the task: reading
# Task "reading" added.
# Press Enter to continue...
# To-Do List Application
# 1. Show tasks
# 2. Add task
# 3. Remove task
# 4. Complete task
# 5. Update task
# 6. Exit
# Choose an option: 2
# Enter the task: dancing
# Task "dancing" added.
# Press Enter to continue...
# To-Do List Application
# 1. Show tasks
# 2. Add task
# 3. Remove task
# 4. Complete task
# 5. Update task
# 6. Exit
# Choose an option: 2
# Enter the task: sleeping - 8hrs
# Task "sleeping - 8hrs" added.
# Press Enter to continue...
# To-Do List Application
# 1. Show tasks
# 2. Add task
# 3. Remove task
# 4. Complete task
# 5. Update task
# 6. Exit
# Choose an option: 1
# 1. reading - Not Done
# 2. dancing - Not Done
# 3. sleeping - 8hrs - Not Done
# Press Enter to continue...
# To-Do List Application
# 1. Show tasks
# 2. Add task
# 3. Remove task
# ...
